# %%
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam

# %%
# Caricamento del dataset MNIST

(X_train, y_train), (X_test, y_test) = mnist.load_data()


# Visualizzazione di un esempio

plt.imshow(X_train[0], cmap='gray')

plt.title(f'Etichetta: {y_train[0]}')

plt.show()


# Normalizzazione dei dati, le reti neurali funzionano SOLO con dati normalizzati

X_train = X_train.astype('float32') / 255

X_test = X_test.astype('float32') / 255


# Reshape dei dati

X_train = X_train.reshape(-1, 28*28)

X_test = X_test.reshape(-1, 28*28)


# Conversione delle etichette in formato one-hotencoding

y_train = to_categorical(y_train, num_classes=10)

y_test = to_categorical(y_test, num_classes=10)

# %%
# Creazione del modello

model = Sequential()


# Aggiunta degli strati

model.add(Dense(units=128, activation='relu', input_shape=(784,)))

model.add(Dropout(0.3))

model.add(Dense(units=64, activation='relu'))

model.add(Dropout(0.3))

model.add(Dense(units=10, activation='softmax'))
# Out:
# C:\Users\User_Valerio\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt = Adam(learning_rate=0.001)

# %%
model.compile(optimizer=opt,

              loss='categorical_crossentropy',

              metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# 1. Stop training if val_loss doesn't improve for 7 epochs
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=7, 
    restore_best_weights=True,
    verbose=1
)

# 2. Halve the Learning Rate if val_loss doesn't improve for 3 epochs
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5,      # Factor by which the learning rate will be reduced (0.5 = half)
    patience=3,      # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6,     # Lower bound on the learning rate
    verbose=1
)

# %%
history = model.fit(X_train, y_train,

                    epochs=100,

                    batch_size=64,

                    validation_split=0.1,

                    callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.8536 - loss: 0.4783 - val_accuracy: 0.9598 - val_loss: 0.1412 - learning_rate: 0.0010
# Epoch 2/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9330 - loss: 0.2297 - val_accuracy: 0.9675 - val_loss: 0.1051 - learning_rate: 0.0010
# Epoch 3/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9462 - loss: 0.1834 - val_accuracy: 0.9712 - val_loss: 0.0947 - learning_rate: 0.0010
# Epoch 4/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9546 - loss: 0.1538 - val_accuracy: 0.9727 - val_loss: 0.0892 - learning_rate: 0.0010
# Epoch 5/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9604 - loss: 0.1348 - val_accuracy: 0.9772 - val_loss: 0.0764 - learning_rate: 0.0010
# Epoch 6/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9632 - loss: 0.1220 - val_accuracy: 0.9778 - val_loss: 0.0776 - learning_rate: 0.0010
# Epoch 7/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9672 - loss: 0.1094 - val_accuracy: 0.9773 - val_loss: 0.0744 - learning_rate: 0.0010
# Epoch 8/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9683 - loss: 0.1039 - val_accuracy: 0.9773 - val_loss: 0.0708 - learning_rate: 0.0010
# Epoch 9/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9704 - loss: 0.0963 - val_accuracy: 0.9803 - val_loss: 0.0728 - learning_rate: 0.0010
# Epoch 10/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9716 - loss: 0.0932 - val_accuracy: 0.9792 - val_loss: 0.0702 - learning_rate: 0.0010
# Epoch 11/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9729 - loss: 0.0887 - val_accuracy: 0.9790 - val_loss: 0.0706 - learning_rate: 0.0010
# Epoch 12/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9742 - loss: 0.0855 - val_accuracy: 0.9788 - val_loss: 0.0714 - learning_rate: 0.0010
# Epoch 13/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9756 - loss: 0.0779 - val_accuracy: 0.9807 - val_loss: 0.0657 - learning_rate: 0.0010
# Epoch 14/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9763 - loss: 0.0762 - val_accuracy: 0.9803 - val_loss: 0.0684 - learning_rate: 0.0010
# Epoch 15/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9775 - loss: 0.0727 - val_accuracy: 0.9823 - val_loss: 0.0646 - learning_rate: 0.0010
# Epoch 16/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9766 - loss: 0.0726 - val_accuracy: 0.9812 - val_loss: 0.0687 - learning_rate: 0.0010
# Epoch 17/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9785 - loss: 0.0690 - val_accuracy: 0.9800 - val_loss: 0.0690 - learning_rate: 0.0010
# Epoch 18/100
# 842/844 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9799 - loss: 0.0654
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9787 - loss: 0.0682 - val_accuracy: 0.9828 - val_loss: 0.0712 - learning_rate: 0.0010
# Epoch 19/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9820 - loss: 0.0564 - val_accuracy: 0.9825 - val_loss: 0.0663 - learning_rate: 5.0000e-04
# Epoch 20/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9837 - loss: 0.0523 - val_accuracy: 0.9815 - val_loss: 0.0675 - learning_rate: 5.0000e-04
# Epoch 21/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9834 - loss: 0.0517
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9834 - loss: 0.0509 - val_accuracy: 0.9820 - val_loss: 0.0683 - learning_rate: 5.0000e-04
# Epoch 22/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9857 - loss: 0.0442 - val_accuracy: 0.9835 - val_loss: 0.0622 - learning_rate: 2.5000e-04
# Epoch 23/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9868 - loss: 0.0401 - val_accuracy: 0.9838 - val_loss: 0.0655 - learning_rate: 2.5000e-04
# Epoch 24/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9864 - loss: 0.0421 - val_accuracy: 0.9835 - val_loss: 0.0674 - learning_rate: 2.5000e-04
# Epoch 25/100
# 836/844 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9869 - loss: 0.0392
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9868 - loss: 0.0408 - val_accuracy: 0.9812 - val_loss: 0.0690 - learning_rate: 2.5000e-04
# Epoch 26/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9876 - loss: 0.0375 - val_accuracy: 0.9823 - val_loss: 0.0669 - learning_rate: 1.2500e-04
# Epoch 27/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9889 - loss: 0.0357 - val_accuracy: 0.9830 - val_loss: 0.0673 - learning_rate: 1.2500e-04
# Epoch 28/100
# 841/844 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9891 - loss: 0.0355
# Epoch 28: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9893 - loss: 0.0350 - val_accuracy: 0.9822 - val_loss: 0.0678 - learning_rate: 1.2500e-04
# Epoch 29/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9893 - loss: 0.0344 - val_accuracy: 0.9822 - val_loss: 0.0672 - learning_rate: 6.2500e-05
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 22.

# %%
import matplotlib.pyplot as plt

# Creiamo una figura con due grafici (Sottoplot)
plt.figure(figsize=(12, 5))

# Grafico della Precisione (Accuracy)
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuratezza del Modello')
plt.xlabel('Epoca')
plt.ylabel('Accuracy')
plt.legend()

# Grafico della Perdita (Loss)
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Perdita del Modello')
plt.xlabel('Epoca')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(f'Perdita sul test set: {test_loss:.4f}')

print(f'Accuratezza sul test set: {test_accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9805 - loss: 0.0695
# Perdita sul test set: 0.0695
# Accuratezza sul test set: 0.9805

# %% [markdown]
# # Convoluzionali

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
import numpy as np
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Input
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam

# %%
# 1. Caricamento del dataset Fashion MNIST
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Visualizzazione di un esempio (Capi di abbigliamento invece di cifre)
plt.imshow(X_train[0], cmap='gray')
plt.title(f'Etichetta: {y_train[0]}')
plt.show()

# 2. Normalizzazione
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# 3. Reshape per CNN (Samples, Height, Width, Channels)
# Per le CNN serve la dimensione del canale (1 per scala di grigi)
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# Conversione delle etichette in formato one-hot encoding
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# 4. Creazione del modello Convoluzionale
model = Sequential()

# Input layer (scelta consigliata da Keras 3 invece di input_shape nei layer)
model.add(Input(shape=(28, 28, 1)))

# Primo blocco convoluzionale: estrazione caratteristiche spaziali
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu')) # quello che crea la matrice di trasformazione
model.add(MaxPooling2D(pool_size=(2, 2)))

# Secondo blocco convoluzionale
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Appiattimento e strati densi (simili al tuo codice originale)
model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=10, activation='softmax'))

# %%
# 5. Sommario e Compilazione
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 232,650 (908.79 KB)
#  Trainable params: 232,650 (908.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 6. Callbacks (identici all'originale)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=7, 
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

# %%
# 7. Addestramento
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=64,
                    validation_split=0.1,
                    callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 31s 31ms/step - accuracy: 0.7651 - loss: 0.6482 - val_accuracy: 0.8522 - val_loss: 0.3889 - learning_rate: 0.0010
# Epoch 2/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.8582 - loss: 0.3994 - val_accuracy: 0.8837 - val_loss: 0.3167 - learning_rate: 0.0010
# Epoch 3/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.8778 - loss: 0.3430 - val_accuracy: 0.8862 - val_loss: 0.3050 - learning_rate: 0.0010
# Epoch 4/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.8903 - loss: 0.3089 - val_accuracy: 0.8928 - val_loss: 0.2846 - learning_rate: 0.0010
# Epoch 5/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9006 - loss: 0.2785 - val_accuracy: 0.9023 - val_loss: 0.2621 - learning_rate: 0.0010
# Epoch 6/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9070 - loss: 0.2572 - val_accuracy: 0.9123 - val_loss: 0.2450 - learning_rate: 0.0010
# Epoch 7/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9124 - loss: 0.2411 - val_accuracy: 0.9073 - val_loss: 0.2532 - learning_rate: 0.0010
# Epoch 8/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9179 - loss: 0.2256 - val_accuracy: 0.9113 - val_loss: 0.2447 - learning_rate: 0.0010
# Epoch 9/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9227 - loss: 0.2112 - val_accuracy: 0.9110 - val_loss: 0.2375 - learning_rate: 0.0010
# Epoch 10/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 23s 27ms/step - accuracy: 0.9257 - loss: 0.1986 - val_accuracy: 0.9107 - val_loss: 0.2507 - learning_rate: 0.0010
# Epoch 11/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 27s 32ms/step - accuracy: 0.9312 - loss: 0.1902 - val_accuracy: 0.9180 - val_loss: 0.2368 - learning_rate: 0.0010
# Epoch 12/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.9346 - loss: 0.1770 - val_accuracy: 0.9213 - val_loss: 0.2336 - learning_rate: 0.0010
# Epoch 13/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 24s 29ms/step - accuracy: 0.9364 - loss: 0.1739 - val_accuracy: 0.9158 - val_loss: 0.2455 - learning_rate: 0.0010
# Epoch 14/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.9412 - loss: 0.1593 - val_accuracy: 0.9163 - val_loss: 0.2441 - learning_rate: 0.0010
# Epoch 15/100
# 843/844 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9467 - loss: 0.1479
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.9436 - loss: 0.1547 - val_accuracy: 0.9173 - val_loss: 0.2510 - learning_rate: 0.0010
# Epoch 16/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.9555 - loss: 0.1233 - val_accuracy: 0.9232 - val_loss: 0.2443 - learning_rate: 5.0000e-04
# Epoch 17/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 24s 28ms/step - accuracy: 0.9587 - loss: 0.1122 - val_accuracy: 0.9213 - val_loss: 0.2598 - learning_rate: 5.0000e-04
# Epoch 18/100
# 843/844 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9618 - loss: 0.1035
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.9595 - loss: 0.1075 - val_accuracy: 0.9225 - val_loss: 0.2553 - learning_rate: 5.0000e-04
# Epoch 19/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 25s 30ms/step - accuracy: 0.9666 - loss: 0.0903 - val_accuracy: 0.9245 - val_loss: 0.2686 - learning_rate: 2.5000e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %%
# 8. Visualizzazione Risultati
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuratezza Fashion MNIST')
plt.xlabel('Epoca')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Perdita Fashion MNIST')
plt.xlabel('Epoca')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# 9. Valutazione finale
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Perdita sul test set: {test_loss:.4f}')
print(f'Accuratezza sul test set: {test_accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9123 - loss: 0.2537
# Perdita sul test set: 0.2537
# Accuratezza sul test set: 0.9123

# %%
import datetime
from keras.callbacks import TensorBoard

# 1. Setup the log directory
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# 2. Define the callback
# histogram_freq=1 allows you to see the weights changing in each layer
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# 3. Add it to your model.fit (using the Fashion MNIST CNN from before)
history = model.fit(
    X_train, y_train,
    epochs=10, 
    batch_size=64,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr, tensorboard_callback] # <--- Added here
)
# Out:
# Epoch 1/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 28s 31ms/step - accuracy: 0.9474 - loss: 0.1407 - val_accuracy: 0.9248 - val_loss: 0.2321 - learning_rate: 2.5000e-04
# Epoch 2/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 25s 29ms/step - accuracy: 0.9525 - loss: 0.1290 - val_accuracy: 0.9245 - val_loss: 0.2307 - learning_rate: 2.5000e-04
# Epoch 3/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9549 - loss: 0.1227 - val_accuracy: 0.9237 - val_loss: 0.2376 - learning_rate: 2.5000e-04
# Epoch 4/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 22s 26ms/step - accuracy: 0.9573 - loss: 0.1163 - val_accuracy: 0.9232 - val_loss: 0.2478 - learning_rate: 2.5000e-04
# Epoch 5/10
# 843/844 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9586 - loss: 0.1106
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 26s 30ms/step - accuracy: 0.9589 - loss: 0.1107 - val_accuracy: 0.9238 - val_loss: 0.2486 - learning_rate: 2.5000e-04
# Epoch 6/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - accuracy: 0.9625 - loss: 0.1012 - val_accuracy: 0.9228 - val_loss: 0.2541 - learning_rate: 1.2500e-04
# Epoch 7/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 34s 41ms/step - accuracy: 0.9649 - loss: 0.0985 - val_accuracy: 0.9245 - val_loss: 0.2538 - learning_rate: 1.2500e-04
# Epoch 8/10
# 843/844 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9658 - loss: 0.0948
# Epoch 8: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 31s 37ms/step - accuracy: 0.9651 - loss: 0.0951 - val_accuracy: 0.9227 - val_loss: 0.2547 - learning_rate: 1.2500e-04
# Epoch 9/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 21s 24ms/step - accuracy: 0.9674 - loss: 0.0913 - val_accuracy: 0.9257 - val_loss: 0.2547 - learning_rate: 6.2500e-05
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %%
# !tensorboard --logdir logs # si apre su http://localhost:6006
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\User_Valerio\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\Scripts\tensorboard.exe\__main__.py", line 4, in <module>
#   File "C:\Users\User_Valerio\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorboard\main.py", line 27, in <module>
#     from tensorboard import default
#   File "C:\Users\User_Valerio\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\tensorboard\default.py", line 30, in <module>
#     import pkg_resources
# ModuleNotFoundError: No module named 'pkg_resources'
